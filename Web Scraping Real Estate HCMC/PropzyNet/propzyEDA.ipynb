# %% [markdown]
# # Tham khảo:
# - https://pandas.pydata.org/docs/user_guide/reshaping.html#reshaping-by-pivoting-dataframe-objects
# - https://pandas.pydata.org/docs/user_guide/groupby.html
# - https://pandas.pydata.org/docs/getting_started/intro_tutorials/06_calculate_statistics.html
# - https://pandas.pydata.org/docs/getting_started/intro_tutorials/07_reshape_table_layout.html
# - https://pandas.pydata.org/docs/getting_started/intro_tutorials/08_combine_dataframes.html
# - https://www.datacamp.com/tutorial/pandas-multi-index

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
pd.set_option('display.max_column',None)

# %%
df = pd.read_csv('post_propzy.csv')
df.head()
# Out:
#    item_code                                          item_name  bedroom  \
# 0     387193  Bán Chung Cư Cũ Gò Công Quận 5 - Gần Chợ Kim Biên      1.0
# 1     417224           Bán căn hộ nhà ở xã hội huyện Bình Chánh      1.0
# 2     391821  Bán nhà hẻm an ninh Hồ Thị Kỷ P1 Q10 - Nhà kiê...      2.0
# 3     345253  Bán nhà hẻm quận 4 - Nhà nhỏ, thích hợp gia đì...      1.0
# 4     377209  Bán lô đất nông nghiệp, diện tích 96.1m2 Tân H...      NaN
#
#    bathroom      area direction  \
# 0       1.0     14 m²      Đông
# 1       1.0  34.91 m²       NaN
# 2       1.0    4.3 m²     Đ.Bắc
# 3       1.0   10.2 m²     Đ.Nam
# 4       NaN   96.1 m²     T.Nam
#
#                                              address total_price  \
# 0                  Đ.Gò Công, P.13, Q.5, Hồ Chí Minh   750 triệu
# 1  Đ.Hương Lộ 80, X.Vĩnh Lộc A, H.Bình Chánh, Hồ ...   780 triệu
# 2                Đ.Hồ Thị Kỷ, P.1, Q.10, Hồ Chí Minh   900 triệu
# 3                  Đ.Tôn Đản, P.10, Q.4, Hồ Chí Minh   930 triệu
# 4         Đ.TL15, X.Tân Hiệp, H.Hóc Môn, Hồ Chí Minh   950 triệu
#
#        unit_price gross_unit_price           payment  property_Phòng ngủ  \
# 0             NaN    53,5 triệu/m²  7,74 triệu/tháng                 1.0
# 1             NaN    22,3 triệu/m²  8,05 triệu/tháng                 1.0
# 2  196,5 triệu/m²   209,3 triệu/m²  9,29 triệu/tháng                 2.0
# 3   83,7 triệu/m²    91,1 triệu/m²   9,6 triệu/tháng                 1.0
# 4             NaN     9,8 triệu/m²   9,8 triệu/tháng                 NaN
#
#    property_Phòng tắm property_Diện tích sử dụng property_Hướng  \
# 0                 1.0                      14 m²           Đông
# 1                 1.0                   34.91 m²            NaN
# 2                 1.0                    12.9 m²          Đ.Bắc
# 3                 1.0                    20.4 m²          Đ.Nam
# 4                 NaN                        NaN          T.Nam
#
#   property_Hiện trạng nhà property_Giấy tờ property_Chiều dài  \
# 0                     NaN          Sổ hồng                NaN
# 1                     NaN              NaN                NaN
# 2                     NaN          Sổ hồng             2.11 m
# 3                  Đang ở          Sổ hồng                4 m
# 4                     NaN          Sổ hồng             19.4 m
#
#   property_Chiều rộng property_Diện tích đất property_Độ rộng hẻm  \
# 0                 NaN                    NaN                  NaN
# 1                 NaN                    NaN                  NaN
# 2              2.22 m                 4.3 m²                  1 m
# 3               2.5 m                10.2 m²                1.8 m
# 4                 5 m                96.1 m²                  2 m
#
#   property_Kết cấu nhà  property_Năm xây dựng property_Độ rộng mặt tiền đường  \
# 0                  NaN                    NaN                             NaN
# 1                  NaN                    NaN                             NaN
# 2       1 trệt + 2 lầu                    NaN                             NaN
# 3       1 trệt + 1 lầu                    NaN                             NaN
# 4                  NaN                    NaN                             NaN
#
#   utility_Na utility_Gần chợ, siêu thị utility_Gần trường học  \
# 0       True                       NaN                    NaN
# 1       True                       NaN                    NaN
# 2       True                       NaN                    NaN
# 3        NaN                      True                   True
# 4        NaN                      True                   True
#
#   utility_Di chuyển thuận tiện ra trung tâm utility_Thiết kế thông thoáng  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                      True                          True
# 4                                       NaN                           NaN
#
#   utility_Khu vực an ninh, yên tĩnh utility_Gần mặt tiền đường  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                              True                        NaN
# 4                               NaN                       True
#
#   utility_Gần bệnh viện utility_Gần công viên, trung tâm  \
# 0                   NaN                              NaN
# 1                   NaN                              NaN
# 2                   NaN                              NaN
# 3                   NaN                              NaN
# 4                   NaN                              NaN
#
#   utility_Sân để xe rộng rãi utility_Hẻm thông utility_Cần bán gấp  \
# 0                        NaN               NaN                 NaN
# 1                        NaN               NaN                 NaN
# 2                        NaN               NaN                 NaN
# 3                        NaN               NaN                 NaN
# 4                        NaN               NaN                 NaN
#
#   utility_Nở hậu utility_2 Mặt hẻm utility_2 Mặt đường chính
# 0            NaN               NaN                       NaN
# 1            NaN               NaN                       NaN
# 2            NaN               NaN                       NaN
# 3            NaN               NaN                       NaN
# 4            NaN               NaN                       NaN

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1472, step=1)

# %%
df.columns
# Out:
# Index(['item_code', 'item_name', 'bedroom', 'bathroom', 'area', 'direction',
#        'address', 'total_price', 'unit_price', 'gross_unit_price', 'payment',
#        'property_Phòng ngủ', 'property_Phòng tắm',
#        'property_Diện tích sử dụng', 'property_Hướng',
#        'property_Hiện trạng nhà', 'property_Giấy tờ', 'property_Chiều dài',
#        'property_Chiều rộng', 'property_Diện tích đất', 'property_Độ rộng hẻm',
#        'property_Kết cấu nhà', 'property_Năm xây dựng',
#        'property_Độ rộng mặt tiền đường', 'utility_Na',
#        'utility_Gần chợ, siêu thị', 'utility_Gần trường học',
#        'utility_Di chuyển thuận tiện ra trung tâm',
#        'utility_Thiết kế thông thoáng', 'utility_Khu vực an ninh, yên tĩnh',
#        'utility_Gần mặt tiền đường', 'utility_Gần bệnh viện',
#        'utility_Gần công viên, trung tâm', 'utility_Sân để xe rộng rãi',
#        'utility_Hẻm thông', 'utility_Cần bán gấp', 'utility_Nở hậu',
#        'utility_2 Mặt hẻm', 'utility_2 Mặt đường chính'],
#       dtype='object')

# %%
df = df.rename(columns = {'item_code':'Mã tin',
                          'item_name':'Tiêu đề',
                          'bedroom':'Phòng ngủ',
                          'bathroom':'Phòng tắm',
                          'area':'Diện tích đất',
                          'direction':'Hướng',
                          'address':'Địa chỉ',
                          'total_price':'Giá',
                          'gross_unit_price':'Đơn giá gộp',
                          'property_Diện tích sử dụng':'Diện tích sử dụng',
                          'property_Hiện trạng nhà':'Hiện trạng nhà',
                          'property_Giấy tờ':'Giấy tờ',
                          'property_Chiều dài':'Chiều dài',
                          'property_Chiều rộng':'Chiều rộng',
                          'property_Độ rộng hẻm':'Độ rộng hẻm',
                          'property_Kết cấu nhà':'Kết cấu nhà',
                          'property_Độ rộng mặt tiền đường':'Độ rộng mặt tiền đường',
                          'utility_Gần chợ, siêu thị':'Gần chợ, siêu thị',
                          'utility_Gần trường học':'Gần trường học',
                          'utility_Di chuyển thuận tiện ra trung tâm':'Di chuyển thuận tiện ra trung tâm',
                          'utility_Khu vực an ninh, yên tĩnh':'Khu vực an ninh, yên tĩnh'
                         })
df.head()
# Out:
#    Mã tin                                            Tiêu đề  Phòng ngủ  \
# 0  387193  Bán Chung Cư Cũ Gò Công Quận 5 - Gần Chợ Kim Biên        1.0
# 1  417224           Bán căn hộ nhà ở xã hội huyện Bình Chánh        1.0
# 2  391821  Bán nhà hẻm an ninh Hồ Thị Kỷ P1 Q10 - Nhà kiê...        2.0
# 3  345253  Bán nhà hẻm quận 4 - Nhà nhỏ, thích hợp gia đì...        1.0
# 4  377209  Bán lô đất nông nghiệp, diện tích 96.1m2 Tân H...        NaN
#
#    Phòng tắm Diện tích đất  Hướng  \
# 0        1.0         14 m²   Đông
# 1        1.0      34.91 m²    NaN
# 2        1.0        4.3 m²  Đ.Bắc
# 3        1.0       10.2 m²  Đ.Nam
# 4        NaN       96.1 m²  T.Nam
#
#                                              Địa chỉ        Giá  \
# 0                  Đ.Gò Công, P.13, Q.5, Hồ Chí Minh  750 triệu
# 1  Đ.Hương Lộ 80, X.Vĩnh Lộc A, H.Bình Chánh, Hồ ...  780 triệu
# 2                Đ.Hồ Thị Kỷ, P.1, Q.10, Hồ Chí Minh  900 triệu
# 3                  Đ.Tôn Đản, P.10, Q.4, Hồ Chí Minh  930 triệu
# 4         Đ.TL15, X.Tân Hiệp, H.Hóc Môn, Hồ Chí Minh  950 triệu
#
#        unit_price     Đơn giá gộp           payment  property_Phòng ngủ  \
# 0             NaN   53,5 triệu/m²  7,74 triệu/tháng                 1.0
# 1             NaN   22,3 triệu/m²  8,05 triệu/tháng                 1.0
# 2  196,5 triệu/m²  209,3 triệu/m²  9,29 triệu/tháng                 2.0
# 3   83,7 triệu/m²   91,1 triệu/m²   9,6 triệu/tháng                 1.0
# 4             NaN    9,8 triệu/m²   9,8 triệu/tháng                 NaN
#
#    property_Phòng tắm Diện tích sử dụng property_Hướng Hiện trạng nhà  \
# 0                 1.0             14 m²           Đông            NaN
# 1                 1.0          34.91 m²            NaN            NaN
# 2                 1.0           12.9 m²          Đ.Bắc            NaN
# 3                 1.0           20.4 m²          Đ.Nam         Đang ở
# 4                 NaN               NaN          T.Nam            NaN
#
#    Giấy tờ Chiều dài Chiều rộng property_Diện tích đất Độ rộng hẻm  \
# 0  Sổ hồng       NaN        NaN                    NaN         NaN
# 1      NaN       NaN        NaN                    NaN         NaN
# 2  Sổ hồng    2.11 m     2.22 m                 4.3 m²         1 m
# 3  Sổ hồng       4 m      2.5 m                10.2 m²       1.8 m
# 4  Sổ hồng    19.4 m        5 m                96.1 m²         2 m
#
#       Kết cấu nhà  property_Năm xây dựng Độ rộng mặt tiền đường utility_Na  \
# 0             NaN                    NaN                    NaN       True
# 1             NaN                    NaN                    NaN       True
# 2  1 trệt + 2 lầu                    NaN                    NaN       True
# 3  1 trệt + 1 lầu                    NaN                    NaN        NaN
# 4             NaN                    NaN                    NaN        NaN
#
#   Gần chợ, siêu thị Gần trường học Di chuyển thuận tiện ra trung tâm  \
# 0               NaN            NaN                               NaN
# 1               NaN            NaN                               NaN
# 2               NaN            NaN                               NaN
# 3              True           True                              True
# 4              True           True                               NaN
#
#   utility_Thiết kế thông thoáng Khu vực an ninh, yên tĩnh  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                          True                      True
# 4                           NaN                       NaN
#
#   utility_Gần mặt tiền đường utility_Gần bệnh viện  \
# 0                        NaN                   NaN
# 1                        NaN                   NaN
# 2                        NaN                   NaN
# 3                        NaN                   NaN
# 4                       True                   NaN
#
#   utility_Gần công viên, trung tâm utility_Sân để xe rộng rãi  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
#
#   utility_Hẻm thông utility_Cần bán gấp utility_Nở hậu utility_2 Mặt hẻm  \
# 0               NaN                 NaN            NaN               NaN
# 1               NaN                 NaN            NaN               NaN
# 2               NaN                 NaN            NaN               NaN
# 3               NaN                 NaN            NaN               NaN
# 4               NaN                 NaN            NaN               NaN
#
#   utility_2 Mặt đường chính
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %% [markdown]
# ## Clean data

# %%
# diện tích đất 
df['Diện tích đất'] = df['Diện tích đất'].apply(lambda x: float(re.findall('[\d\.\d]+',x)[0]))
df['Diện tích đất'] # m²
# Out:
# 0        14.00
# 1        34.91
# 2         4.30
# 3        10.20
# 4        96.10
#          ...
# 1467     90.00
# 1468     79.80
# 1469     96.50
# 1470     51.30
# 1471    200.00
# Name: Diện tích đất, Length: 1472, dtype: float64

# %%
# diện tích sử dụng
def price4use(text):
    res=''
    if pd.isnull(text):
        res =np.nan
    else:
        res = float(re.findall('[\d\.\d]+',text)[0])
    return res

df['Diện tích sử dụng'] = df['Diện tích sử dụng'].apply(lambda x: price4use(x))
df['Diện tích sử dụng'] # m²
# Out:
# 0        14.00
# 1        34.91
# 2        12.90
# 3        20.40
# 4          NaN
#          ...
# 1467    243.30
# 1468    399.10
# 1469    116.70
# 1470    134.20
# 1471    400.00
# Name: Diện tích sử dụng, Length: 1472, dtype: float64

# %%
df['Đơn giá gộp']
# Out:
# 0        53,5 triệu/m²
# 1        22,3 triệu/m²
# 2       209,3 triệu/m²
# 3        91,1 triệu/m²
# 4         9,8 triệu/m²
#              ...
# 1467    216,6 triệu/m²
# 1468    256,8 triệu/m²
# 1469    170,9 triệu/m²
# 1470    311,8 triệu/m²
# 1471       86 triệu/m²
# Name: Đơn giá gộp, Length: 1472, dtype: object

# %%
df['Đơn giá gộp'] = df['Đơn giá gộp'].apply(lambda x: float(re.findall('[\d\,\d]+',x)[0].replace(',','.')))
df['Đơn giá gộp'] # triệu/m²
# Out:
# 0        53.5
# 1        22.3
# 2       209.3
# 3        91.1
# 4         9.8
#         ...
# 1467    216.6
# 1468    256.8
# 1469    170.9
# 1470    311.8
# 1471     86.0
# Name: Đơn giá gộp, Length: 1472, dtype: float64

# %%
df['Giá']
# Out:
# 0       750 triệu
# 1       780 triệu
# 2       900 triệu
# 3       930 triệu
# 4       950 triệu
#           ...
# 1467      19,5 tỷ
# 1468      20,5 tỷ
# 1469      16,5 tỷ
# 1470        16 tỷ
# 1471      17,2 tỷ
# Name: Giá, Length: 1472, dtype: object

# %%
def get_price(text): # đơn vị: tỷ
    res =''
    ty = re.search('[\d\,\d]+.tỷ$',text)
    trieu = re.search('[\d\,\d]+.triệu$',text)
    if ty:
        res = ty.group()
        res = re.findall('[\d\,\d]+',res)[0].replace(',','.')
        res = float(res)
    else:
        res = trieu.group()
        res = float(re.findall('[\d\,\d]+',res)[0])/1000
    
    return res
# 
df['Giá'] = df['Giá'].apply(lambda x: get_price(x))
df['Giá']
# Out:
# 0        0.75
# 1        0.78
# 2        0.90
# 3        0.93
# 4        0.95
#         ...
# 1467    19.50
# 1468    20.50
# 1469    16.50
# 1470    16.00
# 1471    17.20
# Name: Giá, Length: 1472, dtype: float64

# %%
df['Địa chỉ']
# Out:
# 0                       Đ.Gò Công, P.13, Q.5, Hồ Chí Minh
# 1       Đ.Hương Lộ 80, X.Vĩnh Lộc A, H.Bình Chánh, Hồ ...
# 2                     Đ.Hồ Thị Kỷ, P.1, Q.10, Hồ Chí Minh
# 3                       Đ.Tôn Đản, P.10, Q.4, Hồ Chí Minh
# 4              Đ.TL15, X.Tân Hiệp, H.Hóc Môn, Hồ Chí Minh
#                               ...
# 1467                Đ.Số 4A, P.Tân Hưng, Q.7, Hồ Chí Minh
# 1468         Đ.Phạm Huy Thông, P.6, Q.Gò Vấp, Hồ Chí Minh
# 1469    Đ.Xô Viết Nghệ Tĩnh, P.26, Q.Bình Thạnh, Hồ Ch...
# 1470                  Đ.Trường Sa, P.12, Q.3, Hồ Chí Minh
# 1471         Đ.Số 57A, P.Tân Tạo, Q.Bình Tân, Hồ Chí Minh
# Name: Địa chỉ, Length: 1472, dtype: object

# %%
df['Đường'] = df['Địa chỉ'].apply(lambda x: x.split(',')[0].strip())
df['Đường']
# Out:
# 0                 Đ.Gò Công
# 1             Đ.Hương Lộ 80
# 2               Đ.Hồ Thị Kỷ
# 3                 Đ.Tôn Đản
# 4                    Đ.TL15
#                ...
# 1467                Đ.Số 4A
# 1468       Đ.Phạm Huy Thông
# 1469    Đ.Xô Viết Nghệ Tĩnh
# 1470            Đ.Trường Sa
# 1471               Đ.Số 57A
# Name: Đường, Length: 1472, dtype: object

# %%
# Phường/ Xã 
df['Phường'] = df['Địa chỉ'].apply(lambda x: x.split(',')[1].strip())
df['Phường']
# Out:
# 0               P.13
# 1       X.Vĩnh Lộc A
# 2                P.1
# 3               P.10
# 4         X.Tân Hiệp
#             ...
# 1467      P.Tân Hưng
# 1468             P.6
# 1469            P.26
# 1470            P.12
# 1471       P.Tân Tạo
# Name: Phường, Length: 1472, dtype: object

# %%
# Quận / Huyện
df['Quận'] = df['Địa chỉ'].apply(lambda x: x.split(',')[2].strip())
df['Quận']
# Out:
# 0                Q.5
# 1       H.Bình Chánh
# 2               Q.10
# 3                Q.4
# 4          H.Hóc Môn
#             ...
# 1467             Q.7
# 1468        Q.Gò Vấp
# 1469    Q.Bình Thạnh
# 1470             Q.3
# 1471      Q.Bình Tân
# Name: Quận, Length: 1472, dtype: object

# %%
for c in ['Phường', 'Quận']:
    print(f'Column {c}:', set(df[c]),'\n')
# Out:
# Column Phường: {'P.Phú Thuận', 'P.Thới An', 'P.15', 'P.Phú Mỹ', 'P.Bình Trưng Đông', 'P.Cát Lái', 'P.7', 'P.An Phú', 'P.Bình Trị Đông', 'P.Phạm Ngũ Lão', 'khu Hà Đô', 'P.Tân Định', 'P.Tân Thuận Tây', 'P.Long Phước', 'X.Trung Chánh', 'X.Vĩnh Lộc A', 'P.2', 'P.Phước Bình', 'P.19', 'P.Tân Sơn Nhì', 'P.Bình Chiểu', 'P.4', 'P.24', 'X.An Phú Tây', 'P.Hiệp Tân', 'P.Bình Thọ', 'P.Bình Trưng Tây', 'P.8', 'P.Tây Thạnh', 'X.Tân Xuân', 'P.Bình Hưng Hòa A', 'P.Phú Thọ Hòa', 'X.Phước Kiển', 'P.Tam Bình', 'X.Nhị Bình', 'P.Tân Quy', 'P.Trường Thạnh', 'P.Tân Tạo A', 'P.An Lạc', 'X.Bình Hưng', 'P.Linh Đông', 'P.Bình Thuận', 'X.Xuân Thới Thượng', 'P.Bình Trị Đông A', 'X.Hiệp Phước', 'X.Đông Thạnh', 'X.Hóc Môn', 'P.28', 'P.1', 'X.Phong Phú', 'X.Vĩnh Lộc B', 'P.27', 'P.Hiệp Bình Phước', 'P.Bình An', 'P.Linh Chiểu', 'P.Cầu Ông Lãnh', 'P.Thạnh Xuân', 'X.Tân Hiệp', 'P.Tân Tạo', 'Thị trấn Nhà Bè', 'P.An Phú Đông', 'P.6', 'P.Long Bình', 'X.Bà Điểm', 'P.17', 'P.Đa Kao', 'X.Tân Quý Tây', 'P.Linh Xuân', 'P.Linh Trung', 'X.Bình Chánh', 'P.Bến Thành', 'P.21', 'P.Cô Giang', 'P.Tân Thới Hòa', 'P.Tân Thành', 'P.Bình Hưng Hòa', 'X.Tân Túc', 'P.12', 'P.9', 'P.22', 'P.Tân Thuận Đông', 'X.Lê Minh Xuân', 'X.Đa Phước', 'P.14', 'P.18', 'P.11', 'P.Linh Tây', 'X.Phạm Văn Hai', 'P.Thảo Điền', 'X.Thới Tam Thôn', 'P.Phú Trung', 'P.Phú Hữu', 'Phường12', 'P.26', 'P.Tân Thới Nhất', 'P.Bình Khánh', 'P.10', 'P.Long Thạnh Mỹ', 'P.Phú Thạnh', 'P.Tân Hưng', 'P.Tân Hưng Thuận', 'P.Thạnh Mỹ Lợi', 'P.Tân Thới Hiệp', 'P.13', 'P.Tân Chánh Hiệp', 'P.Long Trường', 'X.Nhơn Đức', 'P.Trường Thọ', 'P.Hiệp Phú', 'X.Phú Xuân', 'P.Bến Nghé', 'P.Hòa Thạnh', 'X.Tân Nhựt', 'X.Bình Lợi', 'P.Tăng Nhơn Phú A', 'P.Nguyễn Thái Bình', 'P.Hiệp Bình Chánh', 'P.Nguyễn Cư Trinh', 'X.Long Thới', 'P.3', 'P.Trung Mỹ Tây', 'P.Đông Hưng Thuận', 'P.Bình Trị Đông B', 'P.Tân Phú', 'P.Thạnh Lộc', 'X.Tân Kiên', 'P.Hiệp Thành', 'P.Phước Long B', 'X.Xuân Thới Đông', 'P.Tăng Nhơn Phú B', 'P.Tân Kiểng', 'X.Xuân Thới Sơn', 'P.Tân Quý', 'P.25', 'P.5', 'P.Sơn Kỳ', 'X.Quy Đức', 'P.Phước Long A', 'P.Tân Phong', 'P.16', 'P.An Lạc A', 'P.Tam Phú', 'P.Bình Hưng Hòa B'}
#
# Column Quận: {'Q.6', 'P.12', 'Q.5', 'H.Hóc Môn', 'Q.Tân Bình', 'Q.9', 'Q.Gò Vấp', 'Q.4', 'Q.Thủ Đức', 'Q.10', 'Q.7', 'Q.Phú Nhuận', 'Q.Bình Tân', 'H.Nhà Bè', 'H.Bình Chánh', 'Q.3', 'Q.1', 'Q.2', 'Q.11', 'Q.8', 'Q.12', 'Q.Tân Phú', 'Q.Bình Thạnh'}

# %%
i = df[df['Quận']=='P.12'].index
df = df.drop(i)
print(set(df['Quận']))
df['Quận'].nunique()
# Out:
# {'Q.6', 'Q.5', 'H.Hóc Môn', 'Q.Tân Bình', 'Q.9', 'Q.Gò Vấp', 'Q.4', 'Q.Thủ Đức', 'Q.10', 'Q.7', 'Q.Phú Nhuận', 'Q.Bình Tân', 'H.Nhà Bè', 'H.Bình Chánh', 'Q.3', 'Q.1', 'Q.2', 'Q.11', 'Q.8', 'Q.12', 'Q.Tân Phú', 'Q.Bình Thạnh'}
# 22

# %%
df['Chiều dài']
# Out:
# 0           NaN
# 1           NaN
# 2        2.11 m
# 3           4 m
# 4        19.4 m
#          ...
# 1467       18 m
# 1468       16 m
# 1469       24 m
# 1470    12.45 m
# 1471       20 m
# Name: Chiều dài, Length: 1471, dtype: object

# %%
def f(text): # chiều dài, chiều rộng, độ rộng hẻm , độ rộng mặt tiền đường
    res =''
    try:
        res = float(re.findall('[\d\.\d]+',text)[0])
    except:
        res = np.nan
    return res

# %%
df['Chiều dài'] = df['Chiều dài'].apply(lambda x: f(x))
df['Chiều dài']
# Out:
# 0         NaN
# 1         NaN
# 2        2.11
# 3        4.00
# 4       19.40
#         ...
# 1467    18.00
# 1468    16.00
# 1469    24.00
# 1470    12.45
# 1471    20.00
# Name: Chiều dài, Length: 1471, dtype: float64

# %%
df['Chiều rộng'] = df['Chiều rộng'].apply(lambda x: f(x))
df['Chiều rộng']
# Out:
# 0         NaN
# 1         NaN
# 2        2.22
# 3        2.50
# 4        5.00
#         ...
# 1467     5.00
# 1468     5.00
# 1469     4.04
# 1470     3.95
# 1471    10.00
# Name: Chiều rộng, Length: 1471, dtype: float64

# %%
df['Độ rộng hẻm'] = df['Độ rộng hẻm'].apply(lambda x: f(x))
df['Độ rộng hẻm']
# Out:
# 0       NaN
# 1       NaN
# 2       1.0
# 3       1.8
# 4       2.0
#        ...
# 1467    NaN
# 1468    NaN
# 1469    NaN
# 1470    NaN
# 1471    NaN
# Name: Độ rộng hẻm, Length: 1471, dtype: float64

# %%
# Độ rộng mặt tiền đường
df['Độ rộng mặt tiền đường'] = df['Độ rộng mặt tiền đường'].apply(lambda x: f(x))
df['Độ rộng mặt tiền đường']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 1467     8.0
# 1468    15.0
# 1469    20.0
# 1470    20.0
# 1471    12.0
# Name: Độ rộng mặt tiền đường, Length: 1471, dtype: float64

# %%
df['Kết cấu nhà']
# Out:
# 0                                                     NaN
# 1                                                     NaN
# 2                                          1 trệt + 2 lầu
# 3                                          1 trệt + 1 lầu
# 4                                                     NaN
#                               ...
# 1467                               1 trệt, 1 lửng + 3 lầu
# 1468    1 trệt, 1 lửng, 1 tầng thượng + 3 lầu, có tầng...
# 1469                                       1 trệt, 1 lửng
# 1470                        1 trệt, 1 tầng thượng + 2 lầu
# 1471                        1 trệt, 1 tầng thượng + 2 lầu
# Name: Kết cấu nhà, Length: 1471, dtype: object

# %%
def lau(text):
    res = ''
    try:
        lau = re.search('[\d]+.lầu', text)
        res = lau.group()
        res = int(re.findall('[\d]+',res)[0])
    except:
        res = np.nan
    return res
# lửng 
def lung(text):
    res = ''
    try:
        lung = re.search('[\d]+.lửng', text)
        res = lung.group()
        res = int(re.findall('[\d]+',res)[0])
    except:
        res = np.nan
    return res
# tầng thượng
def tangthuong(text):
    res = ''
    try:
        tangthuong = re.search('[\d]+.tầng thượng', text)
        res = tangthuong.group()
        res = int(re.findall('[\d]+',res)[0])
    except:
        res = np.nan
    return res

# %%
df['Lầu'] = df['Kết cấu nhà'].apply(lambda x: lau(x)).fillna(0).astype(int)
df['Lầu']
# Out:
# 0       0
# 1       0
# 2       2
# 3       1
# 4       0
#        ..
# 1467    3
# 1468    3
# 1469    0
# 1470    2
# 1471    2
# Name: Lầu, Length: 1471, dtype: int32

# %%
df['Lửng'] = df['Kết cấu nhà'].apply(lambda x: lung(x)).fillna(0).astype(int)
df['Lửng']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1467    1
# 1468    1
# 1469    1
# 1470    0
# 1471    0
# Name: Lửng, Length: 1471, dtype: int32

# %%
df['Tầng thượng'] = df['Kết cấu nhà'].apply(lambda x: tangthuong(x)).fillna(0).astype(int)
df['Tầng thượng']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1467    0
# 1468    1
# 1469    0
# 1470    1
# 1471    1
# Name: Tầng thượng, Length: 1471, dtype: int32

# %%
for c in ['Lầu', 'Lửng', 'Tầng thượng']:
    print('Column {}:'.format(c), set(df[c]))
# Out:
# Column Lầu: {0, 1, 2, 3, 4, 5, 6, 7, 8, 24}
# Column Lửng: {0, 1}
# Column Tầng thượng: {0, 1}

# %%
df.columns
# Out:
# Index(['Mã tin', 'Tiêu đề', 'Phòng ngủ', 'Phòng tắm', 'Diện tích đất', 'Hướng',
#        'Địa chỉ', 'Giá', 'unit_price', 'Đơn giá gộp', 'payment',
#        'property_Phòng ngủ', 'property_Phòng tắm', 'Diện tích sử dụng',
#        'property_Hướng', 'Hiện trạng nhà', 'Giấy tờ', 'Chiều dài',
#        'Chiều rộng', 'property_Diện tích đất', 'Độ rộng hẻm', 'Kết cấu nhà',
#        'property_Năm xây dựng', 'Độ rộng mặt tiền đường', 'utility_Na',
#        'Gần chợ, siêu thị', 'Gần trường học',
#        'Di chuyển thuận tiện ra trung tâm', 'utility_Thiết kế thông thoáng',
#        'Khu vực an ninh, yên tĩnh', 'utility_Gần mặt tiền đường',
#        'utility_Gần bệnh viện', 'utility_Gần công viên, trung tâm',
#        'utility_Sân để xe rộng rãi', 'utility_Hẻm thông',
#        'utility_Cần bán gấp', 'utility_Nở hậu', 'utility_2 Mặt hẻm',
#        'utility_2 Mặt đường chính', 'Đường', 'Phường', 'Quận', 'Lầu', 'Lửng',
#        'Tầng thượng'],
#       dtype='object')

# %%
selected_columns = ['Mã tin','Diện tích đất', 'Diện tích sử dụng', 'Chiều dài', 'Chiều rộng','Độ rộng hẻm','Độ rộng mặt tiền đường', 
                    'Phòng ngủ', 'Phòng tắm', 'Lầu', 'Lửng', 'Tầng thượng',
                    'Hướng', 'Đường','Phường', 'Quận', 'Giá', 'Đơn giá gộp','Tiêu đề','Địa chỉ',
                    'Gần chợ, siêu thị','Gần trường học','Di chuyển thuận tiện ra trung tâm','Khu vực an ninh, yên tĩnh']
                    
df = df.filter(selected_columns, axis =1)
df.head()
# Out:
#    Mã tin  Diện tích đất  Diện tích sử dụng  Chiều dài  Chiều rộng  \
# 0  387193          14.00              14.00        NaN         NaN
# 1  417224          34.91              34.91        NaN         NaN
# 2  391821           4.30              12.90       2.11        2.22
# 3  345253          10.20              20.40       4.00        2.50
# 4  377209          96.10                NaN      19.40        5.00
#
#    Độ rộng hẻm  Độ rộng mặt tiền đường  Phòng ngủ  Phòng tắm  Lầu  Lửng  \
# 0          NaN                     NaN        1.0        1.0    0     0
# 1          NaN                     NaN        1.0        1.0    0     0
# 2          1.0                     NaN        2.0        1.0    2     0
# 3          1.8                     NaN        1.0        1.0    1     0
# 4          2.0                     NaN        NaN        NaN    0     0
#
#    Tầng thượng  Hướng          Đường        Phường          Quận   Giá  \
# 0            0   Đông      Đ.Gò Công          P.13           Q.5  0.75
# 1            0    NaN  Đ.Hương Lộ 80  X.Vĩnh Lộc A  H.Bình Chánh  0.78
# 2            0  Đ.Bắc    Đ.Hồ Thị Kỷ           P.1          Q.10  0.90
# 3            0  Đ.Nam      Đ.Tôn Đản          P.10           Q.4  0.93
# 4            0  T.Nam         Đ.TL15    X.Tân Hiệp     H.Hóc Môn  0.95
#
#    Đơn giá gộp                                            Tiêu đề  \
# 0         53.5  Bán Chung Cư Cũ Gò Công Quận 5 - Gần Chợ Kim Biên
# 1         22.3           Bán căn hộ nhà ở xã hội huyện Bình Chánh
# 2        209.3  Bán nhà hẻm an ninh Hồ Thị Kỷ P1 Q10 - Nhà kiê...
# 3         91.1  Bán nhà hẻm quận 4 - Nhà nhỏ, thích hợp gia đì...
# 4          9.8  Bán lô đất nông nghiệp, diện tích 96.1m2 Tân H...
#
#                                              Địa chỉ Gần chợ, siêu thị  \
# 0                  Đ.Gò Công, P.13, Q.5, Hồ Chí Minh               NaN
# 1  Đ.Hương Lộ 80, X.Vĩnh Lộc A, H.Bình Chánh, Hồ ...               NaN
# 2                Đ.Hồ Thị Kỷ, P.1, Q.10, Hồ Chí Minh               NaN
# 3                  Đ.Tôn Đản, P.10, Q.4, Hồ Chí Minh              True
# 4         Đ.TL15, X.Tân Hiệp, H.Hóc Môn, Hồ Chí Minh              True
#
#   Gần trường học Di chuyển thuận tiện ra trung tâm Khu vực an ninh, yên tĩnh
# 0            NaN                               NaN                       NaN
# 1            NaN                               NaN                       NaN
# 2            NaN                               NaN                       NaN
# 3           True                              True                      True
# 4           True                               NaN                       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1471 entries, 0 to 1471
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Mã tin                             1471 non-null   int64
#  1   Diện tích đất                      1471 non-null   float64
#  2   Diện tích sử dụng                  1344 non-null   float64
#  3   Chiều dài                          1130 non-null   float64
#  4   Chiều rộng                         1130 non-null   float64
#  5   Độ rộng hẻm                        571 non-null    float64
#  6   Độ rộng mặt tiền đường             573 non-null    float64
#  7   Phòng ngủ                          1238 non-null   float64
#  8   Phòng tắm                          1305 non-null   float64
#  9   Lầu                                1471 non-null   int32
#  10  Lửng                               1471 non-null   int32
#  11  Tầng thượng                        1471 non-null   int32
#  12  Hướng                              1286 non-null   object
#  13  Đường                              1471 non-null   object
#  14  Phường                             1471 non-null   object
#  15  Quận                               1471 non-null   object
#  16  Giá                                1471 non-null   float64
#  17  Đơn giá gộp                        1471 non-null   float64
#  18  Tiêu đề                            1471 non-null   object
#  19  Địa chỉ                            1471 non-null   object
#  20  Gần chợ, siêu thị                  1011 non-null   object
#  21  Gần trường học                     949 non-null    object
#  22  Di chuyển thuận tiện ra trung tâm  769 non-null    object
#  23  Khu vực an ninh, yên tĩnh          523 non-null    object
# dtypes: float64(10), int32(3), int64(1), object(10)
# memory usage: 270.1+ KB

# %%
# drop các dữ liệu trùng
print(len(df[df.duplicated()]))
df[df.duplicated(subset=['Mã tin'])]
# Out:
# 17
#       Mã tin  Diện tích đất  Diện tích sử dụng  Chiều dài  Chiều rộng  \
# 97    278159          10.70              21.30       3.95        2.60
# 193   297824          54.88              54.88        NaN         NaN
# 320   320975          34.68              34.68        NaN         NaN
# 321   313032          34.69              34.69        NaN         NaN
# 386   390939          53.00              53.00        NaN         NaN
# 420   172395          64.30              64.30        NaN         NaN
# 513   128371          18.50               9.60       5.00        3.10
# 545   352889          22.70              56.75       8.13        2.75
# 769   158535          73.92             333.62      20.50        2.85
# 994   352732          52.00             195.80      15.00        3.80
# 1059  155054        4438.30                NaN     100.00       45.00
# 1060  252860         293.60              57.80      26.00       11.00
# 1062  373636         192.00             498.80      24.00        8.00
# 1185  140929         150.90             397.10      33.95        4.20
# 1187  261009         316.85             316.85        NaN         NaN
# 1391  260196          52.60             171.80       9.30        5.65
# 1400  313995          63.00             200.00      12.50        5.00
#
#       Độ rộng hẻm  Độ rộng mặt tiền đường  Phòng ngủ  Phòng tắm  Lầu  Lửng  \
# 97           1.69                     NaN        1.0        1.0    1     0
# 193           NaN                     NaN        2.0        2.0    0     0
# 320           NaN                     NaN        1.0        1.0    0     0
# 321           NaN                     NaN        1.0        1.0    0     0
# 386           NaN                     NaN        2.0        1.0    0     0
# 420           NaN                     NaN        2.0        2.0    0     0
# 513          3.00                     NaN        2.0        2.0    1     0
# 545          3.00                     NaN        2.0        2.0    1     0
# 769           NaN                    15.0       15.0       15.0    3     1
# 994           NaN                    10.0        3.0        4.0    3     0
# 1059          NaN                     8.0        NaN        NaN    0     0
# 1060          NaN                    14.0        NaN        NaN    0     0
# 1062          NaN                    12.0        6.0        6.0    3     0
# 1185          NaN                    10.0        8.0        8.0    2     0
# 1187          NaN                     NaN        5.0        3.0    0     0
# 1391         2.00                     NaN        4.0        4.0    2     0
# 1400         5.00                     NaN        3.0        3.0    2     0
#
#       Tầng thượng  Hướng             Đường             Phường          Quận  \
# 97              0  Đ.Bắc     Đ.Nguyễn Biểu                P.1           Q.5
# 193             0  T.Nam         Đ.Cây Keo          P.Tam Phú     Q.Thủ Đức
# 320             0  T.Bắc     Đ.Mai Chí Thọ           P.An Phú           Q.2
# 321             0  T.Bắc     Đ.Mai Chí Thọ           P.An Phú           Q.2
# 386             0    NaN           Đ.số 19        X.Phong Phú  H.Bình Chánh
# 420             0  T.Nam      Đ.số 35 - CL          P.Cát Lái           Q.2
# 513             0    Tây     Đ.Quang Trung               P.10      Q.Gò Vấp
# 545             1    Nam   Đ.Bến Bình Đông               P.14           Q.8
# 769             0  T.Bắc        Đ.Cô Giang     P.Cầu Ông Lãnh           Q.1
# 994             0  T.Nam  Đ.Trần Khắc Chân         P.Tân Định           Q.1
# 1059            0    Bắc  Đ.Dương Công Khi    X.Xuân Thới Sơn     H.Hóc Môn
# 1060            0    Nam           Đ.Số 29  P.Bình Trị Đông B    Q.Bình Tân
# 1062            0    Tây            Đ.Số 3   P.Tân Thuận Đông           Q.7
# 1185            1  T.Nam       Đ.Hát Giang                P.2    Q.Tân Bình
# 1187            0    Nam     Đ.Võ Văn Kiệt                P.3           Q.6
# 1391            1  Đ.Bắc      Đ.Hồ Văn Huê                P.9   Q.Phú Nhuận
# 1400            1    Nam         Đ.Trục 30               P.13  Q.Bình Thạnh
#
#         Giá  Đơn giá gộp                                            Tiêu đề  \
# 97     1.45        135.5  Bán nhà nhỏ xinh trung tâm Quận 5 - Gần TTTM N...
# 193    1.65         30.0  Bán gấp căn hộ 2 phòng ngủ, thuộc chung cư Đạt...
# 320    1.80         51.9  Cần bán căn Officetel, chung cư The Sun Avenue...
# 321    1.80         51.8  Bán căn hộ officetel chung cư The Sun Avenue q...
# 386    1.90         35.8  Bán căn hộ cao cấp 2PN tại chung cư Lovera Vis...
# 420    1.95         30.3  Cần bán gấp căn hộ 2 phòng ngủ dự án CitiHome ...
# 513    2.05        110.8  Bán nhà Quận Gò Vấp - hẻm xe ba gác, khu dân c...
# 545    2.10         92.5  Cần bán gấp nhà riêng phường 14, Quận 8 - Hướn...
# 769   51.00        689.9  Nhà mặt tiền Quận 1, thuận tiện kinh doanh CHD...
# 994   33.00        634.6  BÁN NHÀ PHỐ NGUYÊN CĂN MẶT TIỀN PHƯỜNG TÂN ĐỊN...
# 1059  30.00          6.7  Bán nguyên lô đất 4438.3m2 gồm 5 miếng đã có s...
# 1060  30.00        102.1  Bán đất nền phường Bình Trị Đông B, quận Bình ...
# 1062  30.00        156.2  Bán Nhà Mặt Tiền Đường Số Phường Tân Thuận Đôn...
# 1185  27.00        178.9  Nhà nở hậu xây dựng kiên cố, ngay gần sân bay ...
# 1187  27.00         85.2  Bán Căn Hộ Penthouse Viva Riverside Tiện Ích C...
# 1391   8.00        152.0  Chính chủ bán nhà hẻm an ninh yên tĩnh, cách h...
# 1400   8.00        126.9  Bán nhà 1 trệt 2 lầu mái tole ở khu tái định c...
#
#                                                 Địa chỉ Gần chợ, siêu thị  \
# 97                 Đ.Nguyễn Biểu, P.1, Q.5, Hồ Chí Minh               NaN
# 193        Đ.Cây Keo, P.Tam Phú, Q.Thủ Đức, Hồ Chí Minh              True
# 320           Đ.Mai Chí Thọ, P.An Phú, Q.2, Hồ Chí Minh              True
# 321           Đ.Mai Chí Thọ, P.An Phú, Q.2, Hồ Chí Minh              True
# 386     Đ.số 19, X.Phong Phú, H.Bình Chánh, Hồ Chí Minh              True
# 420           Đ.số 35 - CL, P.Cát Lái, Q.2, Hồ Chí Minh              True
# 513          Đ.Quang Trung, P.10, Q.Gò Vấp, Hồ Chí Minh               NaN
# 545             Đ.Bến Bình Đông, P.14, Q.8, Hồ Chí Minh              True
# 769        Đ.Cô Giang, P.Cầu Ông Lãnh, Q.1, Hồ Chí Minh              True
# 994      Đ.Trần Khắc Chân, P.Tân Định, Q.1, Hồ Chí Minh              True
# 1059  Đ.Dương Công Khi, X.Xuân Thới Sơn, H.Hóc Môn, ...               NaN
# 1060  Đ.Số 29, P.Bình Trị Đông B, Q.Bình Tân, Hồ Chí...              True
# 1062         Đ.Số 3, P.Tân Thuận Đông, Q.7, Hồ Chí Minh              True
# 1185          Đ.Hát Giang, P.2, Q.Tân Bình, Hồ Chí Minh              True
# 1187               Đ.Võ Văn Kiệt, P.3, Q.6, Hồ Chí Minh              True
# 1391        Đ.Hồ Văn Huê, P.9, Q.Phú Nhuận, Hồ Chí Minh               NaN
# 1400         Đ.Trục 30, P.13, Q.Bình Thạnh, Hồ Chí Minh              True
#
#      Gần trường học Di chuyển thuận tiện ra trung tâm  \
# 97              NaN                               NaN
# 193            True                              True
# 320            True                              True
# 321            True                              True
# 386            True                               NaN
# 420            True                               NaN
# 513            True                               NaN
# 545            True                               NaN
# 769            True                              True
# 994            True                              True
# 1059            NaN                               NaN
# 1060           True                              True
# 1062           True                              True
# 1185           True                               NaN
# 1187           True                              True
# 1391            NaN                               NaN
# 1400            NaN                              True
#
#      Khu vực an ninh, yên tĩnh
# 97                         NaN
# 193                       True
# 320                       True
# 321                       True
# 386                        NaN
# 420                        NaN
# 513                       True
# 545                        NaN
# 769                        NaN
# 994                        NaN
# 1059                       NaN
# 1060                      True
# 1062                      True
# 1185                       NaN
# 1187                      True
# 1391                       NaN
# 1400                       NaN

# %%
df = df.drop_duplicates(subset=['Mã tin'])
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Mã tin, Diện tích đất, Diện tích sử dụng, Chiều dài, Chiều rộng, Độ rộng hẻm, Độ rộng mặt tiền đường, Phòng ngủ, Phòng tắm, Lầu, Lửng, Tầng thượng, Hướng, Đường, Phường, Quận, Giá, Đơn giá gộp, Tiêu đề, Địa chỉ, Gần chợ, siêu thị, Gần trường học, Di chuyển thuận tiện ra trung tâm, Khu vực an ninh, yên tĩnh]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1454 entries, 0 to 1471
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Mã tin                             1454 non-null   int64
#  1   Diện tích đất                      1454 non-null   float64
#  2   Diện tích sử dụng                  1328 non-null   float64
#  3   Chiều dài                          1119 non-null   float64
#  4   Chiều rộng                         1119 non-null   float64
#  5   Độ rộng hẻm                        566 non-null    float64
#  6   Độ rộng mặt tiền đường             567 non-null    float64
#  7   Phòng ngủ                          1223 non-null   float64
#  8   Phòng tắm                          1290 non-null   float64
#  9   Lầu                                1454 non-null   int32
#  10  Lửng                               1454 non-null   int32
#  11  Tầng thượng                        1454 non-null   int32
#  12  Hướng                              1270 non-null   object
#  13  Đường                              1454 non-null   object
#  14  Phường                             1454 non-null   object
#  15  Quận                               1454 non-null   object
#  16  Giá                                1454 non-null   float64
#  17  Đơn giá gộp                        1454 non-null   float64
#  18  Tiêu đề                            1454 non-null   object
#  19  Địa chỉ                            1454 non-null   object
#  20  Gần chợ, siêu thị                  998 non-null    object
#  21  Gần trường học                     936 non-null    object
#  22  Di chuyển thuận tiện ra trung tâm  760 non-null    object
#  23  Khu vực an ninh, yên tĩnh          516 non-null    object
# dtypes: float64(10), int32(3), int64(1), object(10)
# memory usage: 266.9+ KB

# %%
# num_col = df.select_dtypes(['int32', 'int64', 'float64'])
# num_col.describe()

# %% [markdown]
# # EDA

# %%
df.groupby('Quận').mean()['Giá'].sort_values()
# Out:
# Quận
# Q.8              4.804414
# H.Bình Chánh     9.255417
# Q.4             14.372500
# Q.Tân Phú       15.745000
# Q.7             17.368000
# H.Nhà Bè        17.600222
# Q.12            17.662542
# Q.Bình Tân      19.745368
# H.Hóc Môn       19.767561
# Q.5             21.650600
# Q.9             22.521724
# Q.Gò Vấp        22.903553
# Q.Phú Nhuận     23.095455
# Q.Bình Thạnh    23.120625
# Q.6             25.044615
# Q.3             28.567647
# Q.2             31.544949
# Q.10            31.804898
# Q.11            32.246957
# Q.Thủ Đức       34.828261
# Q.Tân Bình      36.938095
# Q.1             39.552778
# Name: Giá, dtype: float64

# %%
df['Giá'].describe()
# Out:
# count    1454.000000
# mean       22.245186
# std        35.062250
# min         0.750000
# 25%         1.880000
# 50%         8.000000
# 75%        32.000000
# max       610.000000
# Name: Giá, dtype: float64

# %%
df[df['Giá']==df['Giá'].max()]
# Out:
#      Mã tin  Diện tích đất  Diện tích sử dụng  Chiều dài  Chiều rộng  \
# 640  305298         1997.3                NaN      60.99       39.89
#
#      Độ rộng hẻm  Độ rộng mặt tiền đường  Phòng ngủ  Phòng tắm  Lầu  Lửng  \
# 640          NaN                    50.2        NaN        NaN    0     0
#
#      Tầng thượng  Hướng       Đường     Phường Quận    Giá  Đơn giá gộp  \
# 640            0  T.Bắc  Đ.Trần Não  P.Bình An  Q.2  610.0        305.4
#
#                                                Tiêu đề  \
# 640  Bán lô đất rộng gần 2.000m2, mặt tiền đường Tr...
#
#                                      Địa chỉ Gần chợ, siêu thị Gần trường học  \
# 640  Đ.Trần Não, P.Bình An, Q.2, Hồ Chí Minh               NaN            NaN
#
#     Di chuyển thuận tiện ra trung tâm Khu vực an ninh, yên tĩnh
# 640                               NaN                       NaN

# %%
Quan = df['Quận'].sort_values().unique()
print(Quan)
for x in Quan:
    res = df[df['Quận']==x]['Giá'].mean() # giá trung bình 
    # giá cao nhất 
    # giá thấp nhất 
    
    print(f'Mức giá trung bình tại {x}: ',res)
# Out:
# ['H.Bình Chánh' 'H.Hóc Môn' 'H.Nhà Bè' 'Q.1' 'Q.10' 'Q.11' 'Q.12' 'Q.2'
#  'Q.3' 'Q.4' 'Q.5' 'Q.6' 'Q.7' 'Q.8' 'Q.9' 'Q.Bình Thạnh' 'Q.Bình Tân'
#  'Q.Gò Vấp' 'Q.Phú Nhuận' 'Q.Thủ Đức' 'Q.Tân Bình' 'Q.Tân Phú']
# Mức giá trung bình tại H.Bình Chánh:  9.255416666666669
# Mức giá trung bình tại H.Hóc Môn:  19.767560975609754
# Mức giá trung bình tại H.Nhà Bè:  17.600222222222225
# Mức giá trung bình tại Q.1:  39.55277777777778
# Mức giá trung bình tại Q.10:  31.804897959183673
# Mức giá trung bình tại Q.11:  32.24695652173913
# Mức giá trung bình tại Q.12:  17.662542372881358
# Mức giá trung bình tại Q.2:  31.544949494949492
# Mức giá trung bình tại Q.3:  28.567647058823532
# Mức giá trung bình tại Q.4:  14.3725
# Mức giá trung bình tại Q.5:  21.6506
# Mức giá trung bình tại Q.6:  25.044615384615387
# Mức giá trung bình tại Q.7:  17.368000000000002
# Mức giá trung bình tại Q.8:  4.804414414414414
# Mức giá trung bình tại Q.9:  22.521724137931034
# Mức giá trung bình tại Q.Bình Thạnh:  23.120624999999993
# Mức giá trung bình tại Q.Bình Tân:  19.745368421052632
# Mức giá trung bình tại Q.Gò Vấp:  22.903552631578947
# Mức giá trung bình tại Q.Phú Nhuận:  23.095454545454547
# Mức giá trung bình tại Q.Thủ Đức:  34.82826086956523
# Mức giá trung bình tại Q.Tân Bình:  36.938095238095244
# Mức giá trung bình tại Q.Tân Phú:  15.745000000000001

# %%
df.to_csv('propzy_cleaned.csv')
df.to_excel('propzy_cleaned.xlsx')
